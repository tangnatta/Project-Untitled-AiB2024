# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
geo_df = gpd.read_file(
    ".\\Soil_อบ้านบึง\\Soil_อบ้านบึง\\Soil_อบ้านบึง.shp", encoding="tis-620")

# %%
geo_df.to_crs(crs="EPSG:4326") # tranform to lat long
# Out:
#     FID_Soil25 soilgroup fertility           texture_to  \
# 0            2        59   ปานกลาง        ดินร่วนปนทราย
# 1            4        60   ปานกลาง        ดินร่วนปนทราย
# 2           27      24hi       ต่ำ     ดินทรายปนดินร่วน
# 3           28        44       ต่ำ     ดินทรายปนดินร่วน
# 4           29       44B       ต่ำ     ดินทรายปนดินร่วน
# 5          174       35B       ต่ำ        ดินร่วนปนทราย
# 6          180       40B       ต่ำ        ดินร่วนปนทราย
# 7          191        40       ต่ำ        ดินร่วนปนทราย
# 8          193       40B       ต่ำ        ดินร่วนปนทราย
# 9          196       40C       ต่ำ        ดินร่วนปนทราย
# 10         260       46C       ต่ำ        ดินร่วนปนทราย
# 11         337        17       ต่ำ  ดินร่วนเหนียวปนทราย
# 12         338        18       ต่ำ        ดินร่วนปนทราย
# 13         340         6       ต่ำ  ดินร่วนเหนียวปนทราย
# 14         391        18       ต่ำ        ดินร่วนปนทราย
# 15         392        22       ต่ำ        ดินร่วนปนทราย
# ...

# %%
from pyproj import Transformer
transformer = Transformer.from_crs("EPSG:3857", "EPSG:4326")
transformer.transform(-11705274.6374, 4826473.6922)
# Out:
# (39.72785727727918, -105.15027111593008)

# %%
def xy2latlong(x, y, crs="EPSG:3857", latlong_crs="EPSG:4326"):
    transformer = Transformer.from_crs(crs, latlong_crs)
    return transformer.transform(x, y)
